# %%
import pandas as pd
from bokeh.plotting import figure, show
from bokeh.models import Label
from urllib.request import urlopen
from urllib.error import HTTPError
import pickle
import requests
import datetime as dt
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
import nltk
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
from nltk.corpus import wordnet
import numpy as np
import gzip
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
from sklearn.decomposition import LatentDirichletAllocation
from collections import Counter
from gensim.models import word2vec
# Out:
# /Users/lukehawley/opt/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
corpus=pickle.load(urlopen('https://github.com/Galeforse/DST-Assessment-03/raw/master/Data/main/corpus_5.pkl'))
dictionary=pickle.load(urlopen('https://github.com/Galeforse/DST-Assessment-03/raw/master/Data/main/dictionary_5.pkl'))
print("Reading dictionary from pickle")
# Out:
# Reading dictionary from pickle

# %%
print(dictionary)
# Out:
# Dictionary(301 unique tokens: ['Failed', 'password', 'port', 'Disconnecting', 'authentication']...)

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus, id2word=dictionary, num_topics=4, random_state=100, update_every=1, chunksize=10, passes=10, alpha='symmetric', iterations=100, per_word_topics=True)
print(lda_model.print_topics())
# Out:
# [(0, '0.109*"winbind" + 0.109*"auth" + 0.096*"fail" + 0.055*"request" + 0.055*"wbcLogonUser" + 0.055*"AUTH" + 0.055*"ERROR" + 0.054*"getting" + 0.051*"BREAK" + 0.051*"ATTEMPT"'), (1, '0.489*"password" + 0.253*"port" + 0.249*"Failed" + 0.004*"Accepted" + 0.004*"publickey" + 0.000*"ppsuc" + 0.000*"mail" + 0.000*"allow" + 0.000*"User" + 0.000*"AllowUsers"'), (2, '0.191*"list" + 0.191*"User" + 0.191*"AllowUsers" + 0.191*"allow" + 0.050*"preauth" + 0.017*"disconnect" + 0.016*"Received" + 0.016*"Disconnecting" + 0.016*"many" + 0.015*"authentication"'), (3, '0.469*"user" + 0.426*"Invalid" + 0.035*"invalid" + 0.022*"close" + 0.019*"Connection" + 0.012*"session" + 0.006*"unix" + 0.002*"open" + 0.002*"limit" + 0.001*"subsystem"')]

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()

# %%
lda_display=pyLDAvis.gensim.prepare(lda_model, corpus, dictionary, mds='mmds')
# Out:
# /Users/lukehawley/opt/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
pyLDAvis.display(lda_display, template_type='notebook')
# Out:
# /Users/lukehawley/opt/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis/pyLDAvis/js/ldavis.v1.0.0.css">
#
# <div id="ldavis_el257801403153342834727452443352"></div>
# <script type="text/javascript">
#
# var ldavis_el257801403153342834727452443352_data = {"mdsDat": {"x": [-0.3472859566587012, -0.22827316729913963, 0.24524756872254536, 0.3303115552352955], "y": [-0.238844734986548, 0.34812323859447736, -0.34478626145671776, 0.23550775784878836], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [35.88063235613659, 24.084109689938842, 20.837286971865968, 19.197970982058603]}, "tinfo": {"Term": ["user", "password", "Invalid", "port", "Failed", "User", "AllowUsers", "list", "allow", "winbind", "auth", "fail", "AUTH", "wbcLogonUser", "ERROR", "getting", "preauth", "ATTEMPT", "HHHHH", "POSSIBLE", "BREAK", "request", "invalid", "check", "getaddrinfo", "mapping", "reverse", "close", "Connection", "disconnect", "user", "Invalid", "invalid", "close", "Connection", "session", "unix", "open", "limit", "sftp", "subsystem", "Could", "sigpending", "soft", "account", "access", "grant", "DOMAIN", "FOUND", "give", "valid", "wbcGetpwnam", "deny", "euid", "logname", "rhost", "ruser", "ignore", "retry", "pass", "Write", "client", "input", "userauth", "greendata", "bendcable", "happy", "zayoenterprise", "hichina", "mail", "ppsuc", "User", "list", "AllowUsers", "allow", "preauth", "User", "list", "AllowUsers", "allow", "disconnect", "Received", "static", "comcastbusiness", "identification", "receive", "string", "oregon", "ctinets", "mail", "ppsuc", "dyxnet", "info", "unixbsd", "greendata", "fatal", "peer", "reset", "bendcable", "Read", "socket", "userauth", "input", "opentecnologia", "repo", "Disconnecting", "many", "authentication", "failure", "telnor", "request", "password", "port", "Failed", "Accepted", "publickey", "secure", "service", "euid", "logname", "rhost", "ruser", "ignore", "retry", "pass", "unknown", "error", "information", "retrieve", "succeed", "netio", "kanagawa", "broadband", "nationalcablenetworks", "qala", "connect", "refuse", "none", "channel", "mobiel", "utwente", "bendcable", "mail", "ppsuc", "hichina", "mxhzb", "greendata", "happy", "zayoenterprise", "global", "masti", "info", "unixbsd", "biocomplexity", "boole", "indiana", "host", "redstation", "allow", "User", "list", "AllowUsers", "oregon", "hinet", "hvvc", "HTTP", "comcastbusiness", "ctinets", "dyxnet", "winbind", "auth", "fail", "AUTH", "ERROR", "wbcLogonUser", "getting", "ATTEMPT", "BREAK", "HHHHH", "POSSIBLE", "check", "getaddrinfo", "mapping", "reverse", "Address", "address", "back", "map", "request", "secure", "euid", "logname", "rhost", "ruser", "ignore", "retry", "pass", "unknown", "error", "failure", "authentication", "many", "Disconnecting", "client", "mail", "ppsuc", "bendcable", "Write", "greendata", "happy", "hichina", "User", "list", "AllowUsers", "allow"], "Freq": [623852.0, 377447.0, 566937.0, 195632.0, 191984.0, 170798.0, 170798.0, 170798.0, 170798.0, 77304.0, 77254.0, 68010.0, 39015.0, 39015.0, 39015.0, 38240.0, 44332.0, 36553.0, 36553.0, 36553.0, 36553.0, 46095.0, 46822.0, 28906.0, 28906.0, 28906.0, 28906.0, 29005.0, 25223.0, 15050.0, 623852.1385564347, 566937.1015654141, 46822.03671628487, 29004.546086689115, 25222.779207530366, 16083.039807267845, 7380.3491206682465, 2925.7632023407627, 2645.9422689560556, 1479.9000708861258, 1479.9000708861258, 1323.0338127625419, 1323.0338127625419, 1323.0338127625419, 368.3688673357084, 339.21077461855697, 339.21054247676244, 30.3386909215068, 30.3386909215068, 30.3386909215068, 30.3386909215068, 30.3386909215068, 0.7426861348045266, 0.7425477716451114, 0.7425477716451114, 0.7425477716451114, 0.7425477716451114, 0.7425477716451114, 0.7425477716451114, 0.7425477716451114, 0.8678248441993965, 0.7425479227790922, 53.89901071377041, 53.72690659087547, 4.757955852173829, 3.841741156705396, 2.298237014992439, 1.85434049320414, 1.8339032495175505, 5.369391948369187, 5.369391948369187, 7.7182207611638125, 7.7182207611638125, 7.7182207611638125, 7.7182207611638125, 44330.63149787459, 170787.69639928683, 170787.69639928683, 170787.69639928683, 170787.69639928683, 15049.134584953332, 14336.566588423342, 7985.99462779262, ...
